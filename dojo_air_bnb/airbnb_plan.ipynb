# %%
import pandas as pd

# %%
csv = 'data.csv'
df = pd.read_csv(csv)
df.head(2)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   18674   https://www.airbnb.com/rooms/18674  20221211170659   2022-12-11
# 1  124342  https://www.airbnb.com/rooms/124342  20221211170659   2022-12-11
#
#         source                                             name  \
# 0  city scrape  Huge flat for 8 people close to Sagrada Familia
# 1  city scrape  BORN CENTRICO / MUSEO PICASSO / 10 min to BEACH
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Double room at El Born  / MONTHLY RENTAL & DAY...
#
#                                neighborhood_overview  \
# 0  Apartment in Barcelona located in the heart of...
# 1                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/13031453/413c...    71615  ...
# 1  https://a0.muscache.com/pictures/6058611/f5160...   548084  ...
#
# ...

# %%
df2 = df.loc[:,["id","listing_url","name","description","review_scores_value","neighborhood_overview","picture_url"]]
df2.head()
# Out:
#        id                          listing_url  \
# 0   18674   https://www.airbnb.com/rooms/18674
# 1  124342  https://www.airbnb.com/rooms/124342
# 2  128463  https://www.airbnb.com/rooms/128463
# 3  130227  https://www.airbnb.com/rooms/130227
# 4  135513  https://www.airbnb.com/rooms/135513
#
#                                               name  \
# 0  Huge flat for 8 people close to Sagrada Familia
# 1  BORN CENTRICO / MUSEO PICASSO / 10 min to BEACH
# 2              Private Suite in residential area!!
# 3              Spacious Room with Pool and Terrace
# 4          APARTMENT AT RAMBLA POBLE NOU AND BEACH
#
#                                          description  review_scores_value  \
# 0  110m2 apartment to rent in Barcelona. Located ...                 4.28
# 1  Double room at El Born  / MONTHLY RENTAL & DAY...                 4.49
# 2  My House is located in the quiet district of S...                 4.82
# ...

# %%
#df2.to_json('home_air_bnb.json', orient="records")

# %%
df2.columns
# Out:
# Index(['id', 'listing_url', 'name', 'description', 'review_scores_value',
#        'neighborhood_overview', 'picture_url'],
#       dtype='object')

# %%
# page logement == lien vers la page de l'hote qui a le logement
df['host_url']

# logement -- page d'accueil + page logement 
df.picture_url[1]
# Out:
# 'https://a0.muscache.com/pictures/6058611/f5160de0_original.jpg'

# %%
df.picture_url[1]
